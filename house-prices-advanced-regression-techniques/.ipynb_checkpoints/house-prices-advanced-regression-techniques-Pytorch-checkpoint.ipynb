# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %%
X = pd.read_csv('input/train.csv')
test = pd.read_csv('input/test.csv')

# %% [markdown]
# # Explore Numeric Data

# %% [markdown]
# Identifies numeric columns in a dataset and prints them out.

# %%
numeric_columns = []
numeric_columns.extend(list(X.dtypes[X.dtypes == np.int64].index))
numeric_columns.extend(list(X.dtypes[X.dtypes == np.float64].index))
print(numeric_columns)
# Out:
# ['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice', 'LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %% [markdown]
# Remove the **Id** and **SalePrice** columns from the numeric columns because **Id** is the identifier and **SalePrice** is the target variable.

# %%
numeric_columns.remove('Id')
numeric_columns.remove('SalePrice')

# %%
numeric_X = pd.DataFrame(X, columns=numeric_columns)
numeric_X
# Out:
#       MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0             60     8450            7            5       2003          2003
# 1             20     9600            6            8       1976          1976
# 2             60    11250            7            5       2001          2002
# 3             70     9550            7            5       1915          1970
# 4             60    14260            8            5       2000          2000
# ...          ...      ...          ...          ...        ...           ...
# 1455          60     7917            6            5       1999          2000
# 1456          20    13175            6            6       1978          1988
# 1457          70     9042            7            9       1941          2006
# 1458          20     9717            5            6       1950          1996
# 1459          20     9937            5            6       1965          1965
#
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  EnclosedPorch  \
# 0            706           0        150          856  ...              0
# 1            978           0        284         1262  ...              0
# 2            486           0        434          920  ...              0
# 3            216           0        540          756  ...            272
# 4            655           0        490         1145  ...              0
# ...          ...         ...        ...          ...  ...            ...
# 1455           0           0        953          953  ...              0
# 1456         790         163        589         1542  ...              0
# 1457         275           0        877         1152  ...              0
# 1458          49        1029          0         1078  ...            112
# 1459         830         290        136         1256  ...              0
#
#       3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  LotFrontage  \
# 0             0            0         0        0       2    2008         65.0
# 1             0            0         0        0       5    2007         80.0
# 2             0            0         0        0       9    2008         68.0
# 3             0            0         0        0       2    2006         60.0
# 4             0            0         0        0      12    2008         84.0
# ...         ...          ...       ...      ...     ...     ...          ...
# 1455          0            0         0        0       8    2007         62.0
# 1456          0            0         0        0       2    2010         85.0
# 1457          0            0         0     2500       5    2010         66.0
# 1458          0            0         0        0       4    2010         68.0
# 1459          0            0         0        0       6    2008         75.0
#
#       MasVnrArea  GarageYrBlt
# 0          196.0       2003.0
# 1            0.0       1976.0
# 2          162.0       2001.0
# 3            0.0       1998.0
# 4          350.0       2000.0
# ...          ...          ...
# 1455         0.0       1999.0
# 1456       119.0       1978.0
# 1457         0.0       1941.0
# 1458         0.0       1950.0
# 1459         0.0       1965.0
#
# [1460 rows x 36 columns]

# %%
numeric_y = pd.DataFrame(X, columns=['SalePrice'])
numeric_y
# Out:
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1460 rows x 1 columns]

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Check Missing Value

# %%
missing_value = numeric_X.isnull().sum() > 0
print(missing_value[missing_value == True].index)
# Out:
# Index(['LotFrontage', 'MasVnrArea', 'GarageYrBlt'], dtype='object')

# %%
data_to_boxplot = [numeric_X['LotFrontage'], numeric_X['MasVnrArea'], numeric_X['GarageYrBlt']]
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
for i, data in enumerate(data_to_boxplot):
    sns.boxplot(data, ax=axs[i])
    axs[i].set_xlabel('Attributes')
    axs[i].set_ylabel('Value')
plt.tight_layout()
plt.show()

# %% [markdown]
# The code fills the missing values with 0 for the features **LotFrontage** and **MasVnrArea**, while for the feature **GarageYrBlt** the mean value of the feature is used to fill the missing values.

# %%
numeric_X['LotFrontage'] = numeric_X['LotFrontage'].fillna(0)
numeric_X['MasVnrArea'] = numeric_X['MasVnrArea'].fillna(0)
numeric_X['GarageYrBlt'] = numeric_X['GarageYrBlt'].fillna(numeric_X['GarageYrBlt'].mean())

# %%
missing_value = numeric_X.isnull().sum() > 0
print(missing_value[missing_value == True].index)
# Out:
# Index([], dtype='object')

# %% [markdown]
# ## Normalize Data

# %%
scaler_X = StandardScaler()
numeric_X_normalized = scaler_X.fit_transform(numeric_X)

scaler_y = StandardScaler()
numeric_y_normalized = scaler_y.fit_transform(numeric_y.values)

numeric_X = torch.tensor(numeric_X_normalized, dtype=torch.float32)
numeric_y = torch.tensor(numeric_y_normalized, dtype=torch.float32)

# %% [markdown]
# ## Check the shape of input data and target data

# %%
numeric_X.shape, numeric_y.shape
# Out:
# (torch.Size([1460, 36]), torch.Size([1460, 1]))

# %% [markdown]
# # Define the deep learning model

# %% [markdown]
# Four fully connected layers (nn.Linear) are defined, each with a possible dropout layer between them.Dropout is a regularization technique that randomly "discards" (i.e., sets to zero) a portion of the neuron's outputs during the training process, thus reducing the model's dependence on specific training samples and enhancing the model's generalization ability. This reduces the model's dependence on specific training samples and enhances the generalization ability of the model.
#
# The forward method defines the process of forward propagation of data through the network. In this process, the input data first passes through the first fully connected layer, then the ReLU activation function is applied (.clamp(min=0) to ensure that the output is non-negative since the house price cannot be negative), then through the Dropout layer, and finally through the subsequent layers up to the output layer.

# %%
class Net(nn.Module):
    def __init__(self, D_in, H1, H2, H3, D_out):
        super(Net, self).__init__()
        
        self.linear1 = nn.Linear(D_in, H1)
        self.linear2 = nn.Linear(H1, H2)
        self.linear3 = nn.Linear(H2, H3)
        self.linear4 = nn.Linear(H3, D_out)
        
        self.dropout = nn.Dropout(p=0.5)
        
    def forward(self, x):
        y_pred = self.linear1(x).clamp(min=0)
        y_pred = self.dropout(y_pred)
        y_pred = self.linear2(y_pred).clamp(min=0)
        y_pred = self.dropout(y_pred)
        y_pred = self.linear3(y_pred).clamp(min=0)
        y_pred = self.dropout(y_pred)
        y_pred = self.linear4(y_pred)
        return y_pred

# %% [markdown]
# After defining the model structure, the size of each layer needs to be specified.$D_{in}$ is the number of input features, $H1$, $H2$, and $H3$ are the sizes of the hidden layers, and $D_{out}$ is the size of the output layer, which corresponds to the number of target variables to be predicted (in this example, we are predicting only one target: house prices).

# %%
H1, H2, H3 = 500, 1000, 200
D_in, D_out = numeric_X.shape[1], numeric_y.shape[1]

# %%
model = Net(D_in, H1, H2, H3, D_out)

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=1e-4)
criterion = nn.MSELoss()
# Out:
# WARNING:tensorflow:From C:\Users\zengsong\AppData\Roaming\Python\Python310\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
losses = []

for t in range(500):
    y_pred = model(numeric_X)
    
    loss = criterion(y_pred, numeric_y)
    print(t, loss.item())
    losses.append(loss.item())
    
    if torch.isnan(loss):
        break
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# 0 1.0152896642684937
# 1 1.0234723091125488
# 2 1.0280214548110962
# 3 1.0275185108184814
# 4 1.0368645191192627
# 5 1.0191166400909424
# 6 1.0107094049453735
# 7 1.0146130323410034
# 8 1.0214875936508179
# 9 1.02336585521698
# 10 1.0341626405715942
# 11 1.0301101207733154
# 12 1.0159274339675903
# 13 1.0226786136627197
# 14 1.0219911336898804
# 15 1.0238178968429565
# 16 1.02055823802948
# 17 1.0291975736618042
# 18 1.013990044593811
# 19 1.021986484527588
# 20 1.0246520042419434
# 21 1.0173320770263672
# 22 1.0276224613189697
# 23 1.0176810026168823
# 24 1.0203899145126343
# 25 1.017786979675293
# 26 1.0219876766204834
# 27 1.0207972526550293
# 28 1.0266103744506836
# 29 1.0015478134155273
# 30 1.0259182453155518
# 31 1.0185003280639648
# 32 1.0177972316741943
# 33 1.0152902603149414
# 34 1.0259747505187988
# 35 1.0202244520187378
# 36 1.0232757329940796
# 37 1.0195567607879639
# 38 1.0190619230270386
# 39 1.0252169370651245
# 40 1.0317134857177734
# 41 1.0141583681106567
# 42 1.0344353914260864
# 43 1.0176525115966797
# 44 1.0169072151184082
# 45 1.0250002145767212
# 46 1.0137361288070679
# 47 1.0259753465652466
# 48 1.0192170143127441
# 49 1.0256339311599731
# 50 1.0241844654083252
# 51 1.0275838375091553
# 52 1.023450493812561
# 53 1.0171281099319458
# 54 1.0287978649139404
# 55 1.0232783555984497
# 56 1.0135725736618042
# 57 1.024031639099121
# 58 1.0063892602920532
# 59 1.0143448114395142
# 60 1.0191104412078857
# 61 1.0144397020339966
# 62 1.0251729488372803
# 63 1.0232800245285034
# 64 1.0102496147155762
# 65 1.0076500177383423
# 66 1.0130823850631714
# 67 1.0254240036010742
# 68 1.0285595655441284
# 69 1.0092813968658447
# 70 1.01481294631958
# 71 1.0167790651321411
# 72 1.015071988105774
# 73 1.0130443572998047
# 74 1.0299893617630005
# 75 1.0206607580184937
# 76 1.0363603830337524
# 77 1.0255794525146484
# 78 1.0225423574447632
# 79 1.015584111213684
# 80 1.0141093730926514
# 81 1.0138691663742065
# 82 1.0143576860427856
# 83 1.019843339920044
# 84 1.0397930145263672
# 85 1.0282652378082275
# 86 1.0097448825836182
# 87 1.01801598072052
# 88 1.021470069885254
# 89 1.0234146118164062
# 90 1.0251835584640503
# 91 1.0252031087875366
# 92 1.0190129280090332
# 93 1.0252726078033447
# 94 1.0194132328033447
# 95 1.019371747970581
# 96 1.0110743045806885
# 97 1.0129132270812988
# 98 1.0252634286880493
# 99 1.0172467231750488
# 100 1.0190688371658325
# 101 1.019117832183838
# 102 1.0110241174697876
# 103 1.0255742073059082
# 104 1.015452265739441
# 105 1.0182353258132935
# 106 1.0181114673614502
# 107 1.0144100189208984
# 108 1.0106370449066162
# 109 1.0086901187896729
# 110 1.0200209617614746
# 111 1.0052987337112427
# 112 1.0111351013183594
# 113 1.0197629928588867
# 114 1.0257132053375244
# 115 1.0200341939926147
# 116 1.0090947151184082
# 117 1.0124555826187134
# 118 1.0094624757766724
# 119 1.01934015750885
# 120 1.0216623544692993
# 121 1.0101996660232544
# 122 1.0176104307174683
# 123 1.0138163566589355
# 124 1.0213896036148071
# 125 1.0289019346237183
# 126 1.0136616230010986
# 127 1.025315761566162
# 128 1.0234375
# 129 1.0224897861480713
# 130 1.0041728019714355
# 131 1.0233937501907349
# 132 1.0201163291931152
# 133 1.0145004987716675
# 134 1.0152860879898071
# 135 1.0065003633499146
# 136 1.014867901802063
# 137 1.0092220306396484
# 138 1.012041449546814
# 139 1.0144442319869995
# 140 1.0167436599731445
# 141 1.0154070854187012
# 142 1.0178805589675903
# 143 1.0175813436508179
# 144 1.0196678638458252
# 145 1.0202867984771729
# 146 1.020007848739624
# 147 1.024261713027954
# 148 1.0178892612457275
# 149 1.0097393989562988
# 150 1.0073498487472534
# 151 1.0166599750518799
# 152 1.020595908164978
# 153 1.0145442485809326
# 154 1.0127203464508057
# 155 1.0067095756530762
# 156 1.013842225074768
# 157 1.0064786672592163
# 158 1.0118809938430786
# 159 1.0147933959960938
# 160 1.011391043663025
# 161 1.0156110525131226
# 162 1.0123471021652222
# 163 1.0251625776290894
# 164 1.0262516736984253
# 165 1.0181804895401
# 166 1.015607476234436
# 167 1.012138843536377
# 168 1.0170878171920776
# 169 1.025238037109375
# 170 1.009689211845398
# 171 1.019025206565857
# 172 1.0098931789398193
# 173 1.0134589672088623
# 174 1.0019731521606445
# 175 1.0052144527435303
# 176 1.0123263597488403
# 177 1.0234808921813965
# 178 1.0167657136917114
# 179 1.014497995376587
# 180 1.013247013092041
# 181 1.0269275903701782
# 182 1.0152493715286255
# 183 1.0137125253677368
# 184 1.0047427415847778
# 185 1.0035865306854248
# 186 1.0138330459594727
# 187 1.0161609649658203
# 188 1.0041946172714233
# 189 1.0041440725326538
# 190 1.0134756565093994
# 191 1.0230032205581665
# 192 1.0134247541427612
# 193 1.0064862966537476
# 194 1.0067164897918701
# 195 1.0093088150024414
# 196 1.011426329612732
# 197 1.0112398862838745
# 198 1.0048227310180664
# 199 1.0100692510604858
# 200 1.0102940797805786
# 201 1.0115238428115845
# 202 1.0126476287841797
# 203 1.0079915523529053
# 204 1.0101912021636963
# 205 1.0248394012451172
# 206 1.0039618015289307
# 207 1.0156681537628174
# 208 1.0287418365478516
# 209 1.0077708959579468
# 210 1.00758695602417
# 211 1.0079985857009888
# 212 1.0097171068191528
# 213 1.0058525800704956
# 214 1.010617971420288
# 215 1.0239757299423218
# 216 1.01674222946167
# 217 1.0086534023284912
# 218 1.0117214918136597
# 219 1.0148975849151611
# 220 1.0119104385375977
# 221 1.0119297504425049
# 222 1.0113365650177002
# 223 1.0164860486984253
# 224 1.0171923637390137
# 225 1.0144116878509521
# 226 1.0285828113555908
# 227 1.0073957443237305
# 228 1.0173250436782837
# 229 1.0109320878982544
# 230 1.0116510391235352
# 231 1.007173776626587
# 232 1.0128573179244995
# 233 1.0242786407470703
# 234 1.0223180055618286
# 235 1.0034971237182617
# 236 1.018288493156433
# 237 1.0069178342819214
# 238 1.0147159099578857
# 239 0.9996545910835266
# 240 1.01483952999115
# 241 1.0042920112609863
# 242 1.004850149154663
# 243 1.0050327777862549
# 244 1.0142641067504883
# 245 1.0038855075836182
# 246 1.021263837814331
# 247 1.0046892166137695
# 248 1.014093041419983
# 249 1.010337471961975
# 250 1.0111644268035889
# 251 1.0011780261993408
# 252 1.0069842338562012
# 253 1.0147029161453247
# 254 1.0155689716339111
# 255 1.0139132738113403
# 256 1.013244390487671
# 257 1.0181869268417358
# 258 1.0055657625198364
# 259 1.0115190744400024
# 260 0.9998201727867126
# 261 1.012279748916626
# 262 1.0093275308609009
# 263 1.0200047492980957
# 264 1.018087387084961
# 265 1.0050193071365356
# 266 1.007490873336792
# 267 1.0014411211013794
# 268 0.9923369288444519
# 269 1.000139832496643
# 270 1.012657642364502
# 271 1.005833625793457
# 272 1.0100159645080566
# 273 1.0055456161499023
# 274 1.0152685642242432
# 275 1.0025149583816528
# 276 1.0098881721496582
# 277 0.9985398650169373
# 278 1.0093016624450684
# 279 1.0095595121383667
# 280 1.0148775577545166
# 281 1.0105031728744507
# 282 1.0080820322036743
# 283 1.0092159509658813
# 284 1.00131356716156
# 285 1.0015184879302979
# 286 0.9909260869026184
# 287 1.008129358291626
# 288 1.0052499771118164
# 289 1.0082206726074219
# 290 1.0060653686523438
# 291 1.0065242052078247
# 292 1.0109187364578247
# 293 1.005738615989685
# 294 1.0119545459747314
# 295 1.0118896961212158
# 296 1.014336347579956
# 297 0.9898059368133545
# 298 1.0102285146713257
# 299 1.0131789445877075
# 300 1.0021388530731201
# 301 1.0110023021697998
# 302 1.0179357528686523
# 303 1.0201486349105835
# 304 1.0090407133102417
# 305 1.0085458755493164
# 306 1.0020337104797363
# 307 1.012054681777954
# 308 1.0130256414413452
# 309 0.9960378408432007
# 310 1.0209124088287354
# 311 1.0041037797927856
# 312 1.014267921447754
# 313 1.0106924772262573
# 314 1.000692367553711
# 315 0.9996703863143921
# 316 1.0145519971847534
# 317 1.0066007375717163
# 318 0.9887738823890686
# 319 1.008488655090332
# 320 1.0018644332885742
# 321 1.0138943195343018
# 322 1.0026999711990356
# 323 1.0135232210159302
# 324 1.0174065828323364
# 325 1.0091979503631592
# 326 0.991256833076477
# 327 1.002150058746338
# 328 1.012406826019287
# 329 0.9904780983924866
# 330 1.0097298622131348
# 331 1.0140376091003418
# 332 1.0024566650390625
# 333 0.9920380115509033
# 334 1.0010873079299927
# 335 1.0007860660552979
# 336 1.0018508434295654
# 337 1.0053606033325195
# 338 0.9974707961082458
# 339 1.0078014135360718
# 340 1.0039931535720825
# 341 1.0127934217453003
# 342 1.010436773300171
# 343 0.9961680769920349
# 344 1.001258134841919
# 345 1.001257300376892
# 346 1.0038456916809082
# 347 1.00913667678833
# 348 1.0112954378128052
# 349 1.009150505065918
# 350 0.9996636509895325
# 351 1.0074098110198975
# 352 1.0096616744995117
# 353 1.0126854181289673
# 354 1.0108717679977417
# 355 1.0107020139694214
# 356 0.9991983771324158
# 357 1.007241129875183
# 358 1.0135482549667358
# 359 1.0025333166122437
# 360 0.9983126521110535
# 361 1.0189476013183594
# 362 1.016518235206604
# 363 1.000373125076294
# 364 0.9994485378265381
# 365 0.9998313784599304
# 366 1.0088268518447876
# 367 1.0083295106887817
# 368 1.004855751991272
# 369 1.013481616973877
# 370 0.9956480860710144
# 371 0.997977077960968
# 372 1.0123924016952515
# 373 0.9948850274085999
# 374 0.9977155327796936
# 375 0.9974768161773682
# 376 1.00230872631073
# 377 0.9992026090621948
# 378 1.0051170587539673
# 379 1.0001026391983032
# 380 0.9992910027503967
# 381 0.9970585107803345
# 382 0.9942392110824585
# 383 1.0070114135742188
# 384 1.0019985437393188
# 385 1.0076509714126587
# 386 0.9948601722717285
# 387 1.0126354694366455
# 388 1.006222128868103
# 389 1.0053573846817017
# 390 0.9948486089706421
# 391 0.9890034794807434
# 392 1.0028687715530396
# 393 0.9883862733840942
# 394 1.0038859844207764
# 395 1.003343105316162
# 396 0.9932089447975159
# 397 1.0050015449523926
# 398 1.0046080350875854
# 399 0.9967787861824036
# 400 1.0196932554244995
# 401 1.010899543762207
# 402 1.0007402896881104
# 403 0.9937081933021545
# 404 0.9963306188583374
# 405 0.9961122870445251
# 406 0.9995772838592529
# 407 0.9959181547164917
# 408 0.9978352785110474
# 409 1.0009976625442505
# 410 1.014041543006897
# 411 1.0057029724121094
# 412 1.0161619186401367
# 413 0.9993706941604614
# 414 0.9935471415519714
# 415 1.0118317604064941
# 416 1.00398588180542
# 417 1.007500171661377
# 418 1.006207823753357
# 419 1.0034517049789429
# 420 1.0080658197402954
# 421 1.0105392932891846
# 422 1.0154539346694946
# 423 1.0071499347686768
# 424 1.0066334009170532
# 425 1.0043821334838867
# 426 1.0134599208831787
# 427 1.0012770891189575
# 428 0.9927907586097717
# 429 0.9933295249938965
# 430 1.004849910736084
# 431 0.997186541557312
# 432 0.995603621006012
# 433 0.9980632662773132
# 434 1.0060166120529175
# 435 1.000861644744873
# 436 0.9958655834197998
# 437 0.9964934587478638
# 438 1.0016769170761108
# 439 1.0002940893173218
# 440 0.9997811317443848
# 441 1.0142574310302734
# 442 1.0056805610656738
# 443 1.0100172758102417
# 444 0.9995821118354797
# 445 1.001217246055603
# 446 0.9899821877479553
# 447 0.9969189763069153
# 448 0.9894827008247375
# 449 1.0043061971664429
# 450 0.9978530406951904
# 451 1.0003492832183838
# 452 1.0020898580551147
# 453 0.9990933537483215
# 454 0.9989887475967407
# 455 0.9977809190750122
# 456 0.9948936700820923
# 457 0.9956640005111694
# 458 0.9953959584236145
# 459 1.0016204118728638
# 460 1.005200743675232
# 461 0.9944539070129395
# 462 0.9937986731529236
# 463 1.0021119117736816
# 464 0.9958964586257935
# 465 0.9968521595001221
# 466 0.9950897693634033
# 467 0.996654748916626
# 468 0.9981228113174438
# 469 1.0166888236999512
# 470 0.9997121095657349
# 471 0.9980653524398804
# 472 0.9983254671096802
# 473 0.9943774342536926
# 474 1.0063658952713013
# 475 0.991908848285675
# 476 0.9977164268493652
# 477 1.0010560750961304
# 478 1.0080808401107788
# 479 1.0044875144958496
# 480 0.9944566488265991
# 481 0.9931697249412537
# 482 0.9933897852897644
# 483 1.0104544162750244
# 484 0.998887300491333
# 485 1.0003703832626343
# 486 0.9861771464347839
# 487 1.0071505308151245
# 488 1.0092859268188477
# 489 1.0068954229354858
# 490 0.9982113242149353
# 491 0.9938557744026184
# 492 1.0029278993606567
# 493 0.9982467293739319
# 494 0.9948614835739136
# 495 0.9937737584114075
# 496 1.0056054592132568
# 497 0.998610258102417
# 498 1.0008689165115356
# 499 0.9862003922462463

# %%
plt.plot(losses, label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Evaluate the model

# %%
numeric_test_x = pd.DataFrame(test, columns=numeric_columns)
numeric_test_x.head()
# Out:
#    MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0          20    11622            5            6       1961          1961
# 1          20    14267            6            6       1958          1958
# 2          60    13830            5            5       1997          1998
# 3          60     9978            6            6       1998          1998
# 4         120     5005            8            5       1992          1992
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  EnclosedPorch  \
# 0       468.0       144.0      270.0        882.0  ...              0
# 1       923.0         0.0      406.0       1329.0  ...              0
# 2       791.0         0.0      137.0        928.0  ...              0
# 3       602.0         0.0      324.0        926.0  ...              0
# 4       263.0         0.0     1017.0       1280.0  ...              0
#
#    3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  LotFrontage  \
# 0          0          120         0        0       6    2010         80.0
# 1          0            0         0    12500       6    2010         81.0
# 2          0            0         0        0       3    2010         74.0
# 3          0            0         0        0       6    2010         78.0
# 4          0          144         0        0       1    2010         43.0
#
#    MasVnrArea  GarageYrBlt
# 0         0.0       1961.0
# 1       108.0       1958.0
# 2         0.0       1997.0
# 3        20.0       1998.0
# 4         0.0       1992.0
#
# [5 rows x 36 columns]

# %%
for col in numeric_columns:
    numeric_test_x[col].fillna(0)

# %%
scaler_test_x = StandardScaler()
numeric_test_x_normalized = scaler_test_x.fit_transform(numeric_test_x)

numeric_test_x = torch.tensor(numeric_test_x_normalized, dtype=torch.float32)

# %% [markdown]
# Prediction of normalized test data using trained models.

# %%
numeric_test_y = model(torch.tensor(numeric_test_x, dtype=torch.float32))
numeric_test_y
# Out:
# C:\Users\zengsong\AppData\Local\Temp\ipykernel_2012\2299806069.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   numeric_test_y = model(torch.tensor(numeric_test_x, dtype=torch.float32))
# tensor([[-0.0612],
#         [-0.2893],
#         [-0.0691],
#         ...,
#         [-0.0152],
#         [    nan],
#         [-0.1278]], grad_fn=<AddmmBackward0>)

# %%
numeric_test_y[torch.isnan(numeric_test_y)] = 0
numeric_test_y
# Out:
# tensor([[-0.0612],
#         [-0.2893],
#         [-0.0691],
#         ...,
#         [-0.0152],
#         [ 0.0000],
#         [-0.1278]], grad_fn=<IndexPutBackward0>)

# %%
result = pd.DataFrame(numeric_test_y.data.numpy(), columns=['SalePrice'])
result
# Out:
#       SalePrice
# 0     -0.061173
# 1     -0.289312
# 2     -0.069112
# 3      0.003600
# 4      0.015830
# ...         ...
# 1454   0.000000
# 1455  -0.125992
# 1456  -0.015202
# 1457   0.000000
# 1458  -0.127827
#
# [1459 rows x 1 columns]

# %% [markdown]
# Since the forecasts are obtained on standardized data, they need to be converted back to the original scale in order to obtain actual house price forecasts.

# %%
predicted_unnormalized = scaler_y.inverse_transform(numeric_test_y.data.numpy())

result = pd.DataFrame(predicted_unnormalized, columns=['SalePrice'])
result
# Out:
#           SalePrice
# 0     176063.140625
# 1     157945.406250
# 2     175432.687500
# 3     181207.109375
# 4     182178.343750
# ...             ...
# 1454  180921.203125
# 1455  170915.531250
# 1456  179713.953125
# 1457  180921.203125
# 1458  170769.750000
#
# [1459 rows x 1 columns]

# %%
result.isnull().sum()
# Out:
# SalePrice    0
# dtype: int64

# %%
result['Id'] = np.array(result.index)
result['Id'] = result['Id'] + 1461
result = pd.DataFrame(result, columns=['Id', 'SalePrice'])
result.head()
# Out:
#      Id      SalePrice
# 0  1461  176063.140625
# 1  1462  157945.406250
# 2  1463  175432.687500
# 3  1464  181207.109375
# 4  1465  182178.343750

# %%
result.to_csv('output/submission_para.csv', columns=['Id', 'SalePrice'], index=False)
